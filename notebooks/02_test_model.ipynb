# %% [markdown]
# # 02 Test Model
# Test the model inference on sample images.

# %%
import sys
sys.path.append('..')
from src.predict import predict

# Example: 
predict('../data/processed/test/fresh/rotated_by_15_Screen Shot 2018-06-08 at 5.00.18 PM.png')
